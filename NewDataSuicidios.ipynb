# %%
import pandas as pd
import numpy as np

# %%
fname="2. Información preliminar de lesiones fatales de causa externa en Colombia. Enero a diciembre de 2021.xlsx"
#df = pd.read_excel(fname, sheet_name="MUNICIPIO DEL HECHO")
df.rename(columns={ df.columns[0]: "VAR_TYPE" }, inplace = True)
# Variables to be used as indexes
mask1 = df["VAR_TYPE"].str.contains("VARIABLE:")
variables = df[mask1]["VAR_TYPE"]
variables
# Choose correct columns according to the excel structure
MAXCOLS=10020 # from excel file
r1 = np.arange(3, MAXCOLS, 10)
r2 = np.arange(6, MAXCOLS, 10)
cols_idx = np.empty((r1.size + r2.size,), dtype=r1.dtype)
cols_idx[0::2] = r1
cols_idx[1::2] = r2
df.iloc[:, cols_idx]
# 
#df.head(20)
mask_var = df["VAR_TYPE"].str.contains("VARIABLE:")
mask_init = df["VAR_TYPE"].str.contains("VIOLENTA - SUICIDIO")
mask_end = df["VAR_TYPE"].str.contains("VIOLENTA - TRANSPORTE")
index_var = df[mask_var].index
index_init = df[mask_init].index
index_end = df[mask_end].index
#print(index_var)
#print(index_init)
#print(index_end)
rows_idx = np.array([0, 1], dtype=int)
for ii in range(len(index_var)):
    rows_idx = np.r_[rows_idx, index_var[ii], np.arange(index_init[ii]+1,index_end[ii])]
    #rows_idx = np.r_[rows_idx, np.arange(index_init[ii]+1,index_end[ii])]
#indexes
# data extracted
dfnew = df.iloc[rows_idx, np.r_[0, cols_idx]]
dfnew.head(22)
dfnew.to_excel("test1-2021.xlsx")
# Melt the data 
dfnew = dfnew.transpose()
dfnew.columns=dfnew.iloc[0,:]
dfnew.drop(dfnew.index[0], axis=0, inplace=True)
dfnew.rename(columns={"CÓDIGOS DIVIPOLA":"CODE_MUNICIPIO"}, inplace=True)
dfnew.insert(1, "CODE_DPTO", dfnew["CODE_MUNICIPIO"].apply(lambda x: int(x/1000)))
dfnew.to_excel("test2-2021.xlsx")
#dfnew

# %%
df.head(50)
# Out:
#                                              VAR_TYPE  \
# 0                                    CÓDIGOS DIVIPOLA
# 1                                                SEXO
# 2   CONTEXTO DE VIOLENCIA - VARIABLE / MAYOR DE ED...
# 3                             VARIABLE: GRUPO DE EDAD
# 4                              1 VIOLENTA - HOMICIDIO
# 5                                           (00 a 04)
# 6                                           (05 a 09)
# 7                                           (10 a 14)
# 8                                           (15 a 17)
# 9                                           (18 a 19)
# 10                                          (20 a 24)
# 11                                          (25 a 29)
# 12                                          (30 a 34)
# 13                                          (35 a 39)
# 14                                          (40 a 44)
# 15                                          (45 a 49)
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=70a6331b-3e37-4c4d-8041-2d29d0ba96c1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
